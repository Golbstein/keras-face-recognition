# %% [markdown]
# # Build and Train SiameseNet with Triplet Loss
#
# Now when we have the encodings of all faces, we can train small siamese model (even on our laptop) to distinguish whether 2 images show the same person.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# Path to celeb dataset
PATH = '/workspace/AI/OpenSource/celebrities/'
celeb_data = pd.read_csv(PATH + 'identity_CelebA.txt', sep=" ", header=None)
celeb_data.columns = ["image", "label"]

# %%
convfeats = np.load('conv_feats.npy')
labels = celeb_data['label'].values
X_train, X_test, y_train, y_test = train_test_split(convfeats, labels, test_size=0.25)

# %% [markdown]
# ### Create Siamese Model
# Siamese model will encode the conv features to a 256 dim vector that will represent the image.
# Kind of a signature of the images.
#
# The fundamental assumption of this model is that same person should have similar "signatures".

# %%
from keras.layers import Input, Dense, LeakyReLU, Concatenate, Lambda, BatchNormalization
from keras import backend as K
from keras.models import Model

def embedder(conv_feat_size):
    input = Input((conv_feat_size,), name = 'input')
    normalize = Lambda(lambda x: K.l2_normalize(x, axis=-1), name='normalize')
    x = Dense(512)(input)
    x = LeakyReLU(alpha=0.1)(x)
    x = Dense(128)(x)
    x = normalize(x)
    model = Model(input, x)
    return model
    
def get_siamese_model(conv_feat_size = 1024):
    
    input_a = Input( (conv_feat_size,),  name='anchor')
    input_p = Input( (conv_feat_size,),  name='positive')
    input_n = Input( (conv_feat_size,),  name='negative')
    
    emb_model = embedder(conv_feat_size)
    output_a = emb_model(input_a)
    output_p = emb_model(input_p)
    output_n = emb_model(input_n)
    
    merged_vector = Concatenate(axis=-1)([output_a, output_p, output_n])
    model = Model(inputs=[input_a, input_p, input_n],
                  outputs=merged_vector)

    return model

model = get_siamese_model(conv_feat_size = convfeats.shape[1])
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Create Siamese Model Loss - Triplet Loss
#
# Same person should have 'similar' signatures between his images, whilst new person should have differnet signature.
# One way to compare the "similarity" between this signatures (vectors) is to use euclidean distance metric or cosine distance.
#
# I chose to use cosine distance: https://en.wikipedia.org/wiki/Cosine_similarity
# But you can easily change it and check if you're getting better results. If you do, let me know :)
#
# Let's define 3 variables:
# 1. Anchor - The image against which comparisons will be made
# 2. Positive - Different image of the person in the anchor image
# 3. Negative - image of a different person
#
# Our loss is essentially:
#
# ###### Loss = Cos_dist(Anchor, Positive) - Cos_dist(Anchor, Negative) + alpha
#
# for more information visit here: https://towardsdatascience.com/siamese-network-triplet-loss-b4ca82c1aec8

# %%
def triplet_loss(y_true, y_pred, cosine = True, alpha = 0.2, embedding_size = 128):
    
    ind = int(embedding_size * 2)
    a_pred = y_pred[:, :embedding_size]
    p_pred = y_pred[:, embedding_size:ind]
    n_pred = y_pred[:, ind:]
    if cosine:
        positive_distance = 1 - K.sum((a_pred * p_pred), axis=-1)
        negative_distance = 1 - K.sum((a_pred * n_pred), axis=-1)
    else:
        positive_distance = K.sqrt(K.sum(K.square(a_pred - p_pred), axis=-1))
        negative_distance = K.sqrt(K.sum(K.square(a_pred - n_pred), axis=-1))
    loss = K.maximum(0.0, positive_distance - negative_distance + alpha)
    return loss

# %% [markdown]
# ### Create image generator for siamese network
# The input of the model will be mini-batches of [Anchors, Positives, Negatives] conv features of the images.
#
# Don't forget - we train on conv features and not on the origianl images

# %%
from keras.utils import Sequence

class EmbLoader(Sequence):
    def __init__(self, convfeats, labels, batchSize = 16):
        self.X = convfeats
        self.batchSize = batchSize
        self.y = labels
        self.POS = np.zeros((batchSize, convfeats.shape[1]))
        self.NEG = np.zeros((batchSize, convfeats.shape[1]))
    #gets the number of batches this generator returns
    def __len__(self):
        l,rem = divmod(len(self.y), self.batchSize)
        return (l + (1 if rem > 0 else 0))
    #shuffles data on epoch end
    def on_epoch_end(self):
        a = np.arange(len(self.y))
        np.random.shuffle(a)
        self.X = self.X[a]
        self.y = self.y[a]
    #gets a batch with index = i
    def __getitem__(self, i):
        start = i*self.batchSize
        stop  = (i+1)*self.batchSize
        ancor_labels = self.y[start:stop]
        ancors = self.X[start:stop]
        for k, label in enumerate(ancor_labels):
            pos_idx = np.where(self.y==label)[0]
            neg_idx = np.where(self.y!=label)[0]
            self.NEG[k] = self.X[np.random.choice(neg_idx)]
            pos_idx_hat = pos_idx[(pos_idx<start) | (pos_idx>stop)]
            if len(pos_idx_hat):
                self.POS[k] = self.X[np.random.choice(pos_idx_hat)]
            else:
                # positive examples are within the batch or just 1 example in dataset
                self.POS[k] = self.X[np.random.choice(pos_idx)]
        return [ancors, self.POS[:k+1], self.NEG[:k+1]], np.empty(k+1)

# %% [markdown]
# ## Launch training

# %%
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
# Compile the model
model.compile(Adam(lr = 0.00005), loss = triplet_loss)


# create generators
train_gen = EmbLoader(X_train, y_train, batchSize = 64)
valid_gen = EmbLoader(X_test, y_test, batchSize = 64)
all_gen = EmbLoader(convfeats, labels, batchSize = 64)

checkpoint = ModelCheckpoint('siamese.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False)
model.fit_generator(train_gen, steps_per_epoch=len(train_gen), epochs=150, 
                    validation_data=valid_gen, validation_steps=len(valid_gen),
                    workers=8, use_multiprocessing=True, callbacks=[checkpoint])

# train for 50 more epochs with validation data
model.compile(Adam(lr = 0.00002), loss = triplet_loss)
model.load_weights('siamese.h5')
model.fit_generator(all_gen, steps_per_epoch=len(all_gen), epochs=200, initial_epoch = 150,
                    workers=8, use_multiprocessing=True)
model.save('siamese.h5')
# Out:
# Epoch 1/150
# 2375/2375 [==============================] - 23s 10ms/step - loss: 0.0710 - val_loss: 0.0612
#
# Epoch 00001: val_loss improved from inf to 0.06117, saving model to siamese.h5
# Epoch 2/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0588 - val_loss: 0.0578
#
# Epoch 00002: val_loss improved from 0.06117 to 0.05782, saving model to siamese.h5
# Epoch 3/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0556 - val_loss: 0.0553
#
# Epoch 00003: val_loss improved from 0.05782 to 0.05533, saving model to siamese.h5
# Epoch 4/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0531 - val_loss: 0.0543
#
# Epoch 00004: val_loss improved from 0.05533 to 0.05429, saving model to siamese.h5
# Epoch 5/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0521 - val_loss: 0.0527
#
# Epoch 00005: val_loss improved from 0.05429 to 0.05269, saving model to siamese.h5
# Epoch 6/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0508 - val_loss: 0.0508
#
# Epoch 00006: val_loss improved from 0.05269 to 0.05075, saving model to siamese.h5
# Epoch 7/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0498 - val_loss: 0.0508
#
# Epoch 00007: val_loss did not improve from 0.05075
# Epoch 8/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0497 - val_loss: 0.0499
#
# Epoch 00008: val_loss improved from 0.05075 to 0.04992, saving model to siamese.h5
# Epoch 9/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0482 - val_loss: 0.0495
#
# Epoch 00009: val_loss improved from 0.04992 to 0.04946, saving model to siamese.h5
# Epoch 10/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0479 - val_loss: 0.0488
#
# Epoch 00010: val_loss improved from 0.04946 to 0.04876, saving model to siamese.h5
# Epoch 11/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0472 - val_loss: 0.0485
#
# Epoch 00011: val_loss improved from 0.04876 to 0.04851, saving model to siamese.h5
# Epoch 12/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0469 - val_loss: 0.0486
#
# Epoch 00012: val_loss did not improve from 0.04851
# Epoch 13/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0462 - val_loss: 0.0479
#
# Epoch 00013: val_loss improved from 0.04851 to 0.04792, saving model to siamese.h5
# Epoch 14/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0455 - val_loss: 0.0467
#
# Epoch 00014: val_loss improved from 0.04792 to 0.04670, saving model to siamese.h5
# Epoch 15/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0452 - val_loss: 0.0465
#
# Epoch 00015: val_loss improved from 0.04670 to 0.04648, saving model to siamese.h5
# Epoch 16/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0448 - val_loss: 0.0463
#
# Epoch 00016: val_loss improved from 0.04648 to 0.04627, saving model to siamese.h5
# Epoch 17/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0446 - val_loss: 0.0465
#
# Epoch 00017: val_loss did not improve from 0.04627
# Epoch 18/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0435 - val_loss: 0.0468
#
# Epoch 00018: val_loss did not improve from 0.04627
# Epoch 19/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0433 - val_loss: 0.0454
#
# Epoch 00019: val_loss improved from 0.04627 to 0.04536, saving model to siamese.h5
# Epoch 20/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0426 - val_loss: 0.0457
#
# Epoch 00020: val_loss did not improve from 0.04536
# Epoch 21/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0427 - val_loss: 0.0462
#
# Epoch 00021: val_loss did not improve from 0.04536
# Epoch 22/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0424 - val_loss: 0.0461
#
# Epoch 00022: val_loss did not improve from 0.04536
# Epoch 23/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0425 - val_loss: 0.0449
#
# Epoch 00023: val_loss improved from 0.04536 to 0.04487, saving model to siamese.h5
# Epoch 24/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0421 - val_loss: 0.0459
#
# Epoch 00024: val_loss did not improve from 0.04487
# Epoch 25/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0416 - val_loss: 0.0447
#
# Epoch 00025: val_loss improved from 0.04487 to 0.04474, saving model to siamese.h5
# Epoch 26/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0414 - val_loss: 0.0440
#
# Epoch 00026: val_loss improved from 0.04474 to 0.04398, saving model to siamese.h5
# Epoch 27/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0411 - val_loss: 0.0446
#
# Epoch 00027: val_loss did not improve from 0.04398
# Epoch 28/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0412 - val_loss: 0.0445
#
# Epoch 00028: val_loss did not improve from 0.04398
# Epoch 29/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0407 - val_loss: 0.0449
#
# Epoch 00029: val_loss did not improve from 0.04398
# Epoch 30/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0400 - val_loss: 0.0445
#
# Epoch 00030: val_loss did not improve from 0.04398
# Epoch 31/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0398 - val_loss: 0.0446
#
# Epoch 00031: val_loss did not improve from 0.04398
# Epoch 32/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0401 - val_loss: 0.0442
#
# Epoch 00032: val_loss did not improve from 0.04398
# Epoch 33/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0398 - val_loss: 0.0445
#
# Epoch 00033: val_loss did not improve from 0.04398
# Epoch 34/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0397 - val_loss: 0.0438
#
# Epoch 00034: val_loss improved from 0.04398 to 0.04380, saving model to siamese.h5
# Epoch 35/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0395 - val_loss: 0.0442
#
# Epoch 00035: val_loss did not improve from 0.04380
# Epoch 36/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0387 - val_loss: 0.0432
#
# Epoch 00036: val_loss improved from 0.04380 to 0.04319, saving model to siamese.h5
# Epoch 37/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0392 - val_loss: 0.0436
#
# Epoch 00037: val_loss did not improve from 0.04319
# Epoch 38/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0384 - val_loss: 0.0437
#
# Epoch 00038: val_loss did not improve from 0.04319
# Epoch 39/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0383 - val_loss: 0.0434
#
# Epoch 00039: val_loss did not improve from 0.04319
# Epoch 40/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0385 - val_loss: 0.0436
#
# Epoch 00040: val_loss did not improve from 0.04319
# Epoch 41/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0384 - val_loss: 0.0428
#
# Epoch 00041: val_loss improved from 0.04319 to 0.04281, saving model to siamese.h5
# Epoch 42/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0376 - val_loss: 0.0444
#
# Epoch 00042: val_loss did not improve from 0.04281
# Epoch 43/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0375 - val_loss: 0.0436
#
# Epoch 00043: val_loss did not improve from 0.04281
# Epoch 44/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0375 - val_loss: 0.0434
#
# Epoch 00044: val_loss did not improve from 0.04281
# Epoch 45/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0372 - val_loss: 0.0439
#
# Epoch 00045: val_loss did not improve from 0.04281
# Epoch 46/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0376 - val_loss: 0.0424
#
# Epoch 00046: val_loss improved from 0.04281 to 0.04242, saving model to siamese.h5
# Epoch 47/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0368 - val_loss: 0.0429
#
# Epoch 00047: val_loss did not improve from 0.04242
# Epoch 48/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0375 - val_loss: 0.0427
#
# Epoch 00048: val_loss did not improve from 0.04242
# Epoch 49/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0367 - val_loss: 0.0437
#
# Epoch 00049: val_loss did not improve from 0.04242
# Epoch 50/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0367 - val_loss: 0.0435
#
# Epoch 00050: val_loss did not improve from 0.04242
# Epoch 51/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0367 - val_loss: 0.0428
#
# Epoch 00051: val_loss did not improve from 0.04242
# Epoch 52/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0356 - val_loss: 0.0427
#
# Epoch 00052: val_loss did not improve from 0.04242
# Epoch 53/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0360 - val_loss: 0.0437
#
# Epoch 00053: val_loss did not improve from 0.04242
# Epoch 54/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0363 - val_loss: 0.0435
#
# Epoch 00054: val_loss did not improve from 0.04242
# Epoch 55/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0360 - val_loss: 0.0422
#
# Epoch 00055: val_loss improved from 0.04242 to 0.04221, saving model to siamese.h5
# Epoch 56/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0359 - val_loss: 0.0422
#
# Epoch 00056: val_loss did not improve from 0.04221
# Epoch 57/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0357 - val_loss: 0.0420
#
# Epoch 00057: val_loss improved from 0.04221 to 0.04198, saving model to siamese.h5
# Epoch 58/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0351 - val_loss: 0.0426
#
# Epoch 00058: val_loss did not improve from 0.04198
# Epoch 59/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0348 - val_loss: 0.0426
#
# Epoch 00059: val_loss did not improve from 0.04198
# Epoch 60/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0353 - val_loss: 0.0419
#
# Epoch 00060: val_loss improved from 0.04198 to 0.04193, saving model to siamese.h5
# Epoch 61/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0349 - val_loss: 0.0424
#
# Epoch 00061: val_loss did not improve from 0.04193
# Epoch 62/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0343 - val_loss: 0.0429
#
# Epoch 00062: val_loss did not improve from 0.04193
# Epoch 63/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0342 - val_loss: 0.0424
#
# Epoch 00063: val_loss did not improve from 0.04193
# Epoch 64/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0343 - val_loss: 0.0428
#
# Epoch 00064: val_loss did not improve from 0.04193
# Epoch 65/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0346 - val_loss: 0.0420
#
# Epoch 00065: val_loss did not improve from 0.04193
# Epoch 66/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0342 - val_loss: 0.0425
#
# Epoch 00066: val_loss did not improve from 0.04193
# Epoch 67/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0343 - val_loss: 0.0428
#
# Epoch 00067: val_loss did not improve from 0.04193
# Epoch 68/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0343 - val_loss: 0.0431
#
# Epoch 00068: val_loss did not improve from 0.04193
# Epoch 69/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0341 - val_loss: 0.0426
#
# Epoch 00069: val_loss did not improve from 0.04193
# Epoch 70/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0337 - val_loss: 0.0429
#
# Epoch 00070: val_loss did not improve from 0.04193
# Epoch 71/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0334 - val_loss: 0.0427
#
# Epoch 00071: val_loss did not improve from 0.04193
# Epoch 72/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0333 - val_loss: 0.0421
#
# Epoch 00072: val_loss did not improve from 0.04193
# Epoch 73/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0334 - val_loss: 0.0424
#
# Epoch 00073: val_loss did not improve from 0.04193
# Epoch 74/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0332 - val_loss: 0.0423
#
# Epoch 00074: val_loss did not improve from 0.04193
# Epoch 75/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0331 - val_loss: 0.0426
#
# Epoch 00075: val_loss did not improve from 0.04193
# Epoch 76/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0327 - val_loss: 0.0423
#
# Epoch 00076: val_loss did not improve from 0.04193
# Epoch 77/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0330 - val_loss: 0.0422
#
# Epoch 00077: val_loss did not improve from 0.04193
# Epoch 78/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0331 - val_loss: 0.0430
#
# Epoch 00078: val_loss did not improve from 0.04193
# Epoch 79/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0327 - val_loss: 0.0421
#
# Epoch 00079: val_loss did not improve from 0.04193
# Epoch 80/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0331 - val_loss: 0.0432
#
# Epoch 00080: val_loss did not improve from 0.04193
# Epoch 81/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0324 - val_loss: 0.0422
#
# Epoch 00081: val_loss did not improve from 0.04193
# Epoch 82/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0323 - val_loss: 0.0424
#
# Epoch 00082: val_loss did not improve from 0.04193
# Epoch 83/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0321 - val_loss: 0.0429
#
# Epoch 00083: val_loss did not improve from 0.04193
# Epoch 84/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0324 - val_loss: 0.0418
#
# Epoch 00084: val_loss improved from 0.04193 to 0.04182, saving model to siamese.h5
# Epoch 85/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0322 - val_loss: 0.0424
#
# Epoch 00085: val_loss did not improve from 0.04182
# Epoch 86/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0319 - val_loss: 0.0427
#
# Epoch 00086: val_loss did not improve from 0.04182
# Epoch 87/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0318 - val_loss: 0.0416
#
# Epoch 00087: val_loss improved from 0.04182 to 0.04164, saving model to siamese.h5
# Epoch 88/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0321 - val_loss: 0.0420
#
# Epoch 00088: val_loss did not improve from 0.04164
# Epoch 89/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0318 - val_loss: 0.0427
#
# Epoch 00089: val_loss did not improve from 0.04164
# Epoch 90/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0315 - val_loss: 0.0421
#
# Epoch 00090: val_loss did not improve from 0.04164
# Epoch 91/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0320 - val_loss: 0.0421
#
# Epoch 00091: val_loss did not improve from 0.04164
# Epoch 92/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0314 - val_loss: 0.0418
#
# Epoch 00092: val_loss did not improve from 0.04164
# Epoch 93/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0315 - val_loss: 0.0415
#
# Epoch 00093: val_loss improved from 0.04164 to 0.04154, saving model to siamese.h5
# Epoch 94/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0312 - val_loss: 0.0423
#
# Epoch 00094: val_loss did not improve from 0.04154
# Epoch 95/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0311 - val_loss: 0.0420
#
# Epoch 00095: val_loss did not improve from 0.04154
# Epoch 96/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0310 - val_loss: 0.0419
#
# Epoch 00096: val_loss did not improve from 0.04154
# Epoch 97/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0310 - val_loss: 0.0419
#
# Epoch 00097: val_loss did not improve from 0.04154
# Epoch 98/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0314 - val_loss: 0.0428
#
# Epoch 00098: val_loss did not improve from 0.04154
# Epoch 99/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0310 - val_loss: 0.0419
#
# Epoch 00099: val_loss did not improve from 0.04154
# Epoch 100/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0304 - val_loss: 0.0421
#
# Epoch 00100: val_loss did not improve from 0.04154
# Epoch 101/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0306 - val_loss: 0.0428
#
# Epoch 00101: val_loss did not improve from 0.04154
# Epoch 102/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0308 - val_loss: 0.0422
#
# Epoch 00102: val_loss did not improve from 0.04154
# Epoch 103/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0302 - val_loss: 0.0430
#
# Epoch 00103: val_loss did not improve from 0.04154
# Epoch 104/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0305 - val_loss: 0.0423
#
# Epoch 00104: val_loss did not improve from 0.04154
# Epoch 105/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0307 - val_loss: 0.0428
#
# Epoch 00105: val_loss did not improve from 0.04154
# Epoch 106/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0305 - val_loss: 0.0420
#
# Epoch 00106: val_loss did not improve from 0.04154
# Epoch 107/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0300 - val_loss: 0.0427
#
# Epoch 00107: val_loss did not improve from 0.04154
# Epoch 108/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0302 - val_loss: 0.0430
#
# Epoch 00108: val_loss did not improve from 0.04154
# Epoch 109/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0294 - val_loss: 0.0419
#
# Epoch 00109: val_loss did not improve from 0.04154
# Epoch 110/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0298 - val_loss: 0.0428
#
# Epoch 00110: val_loss did not improve from 0.04154
# Epoch 111/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0301 - val_loss: 0.0421
#
# Epoch 00111: val_loss did not improve from 0.04154
# Epoch 112/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0297 - val_loss: 0.0420
#
# Epoch 00112: val_loss did not improve from 0.04154
# Epoch 113/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0295 - val_loss: 0.0424
#
# Epoch 00113: val_loss did not improve from 0.04154
# Epoch 114/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0294 - val_loss: 0.0430
#
# Epoch 00114: val_loss did not improve from 0.04154
# Epoch 115/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0296 - val_loss: 0.0426
#
# Epoch 00115: val_loss did not improve from 0.04154
# Epoch 116/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0293 - val_loss: 0.0432
#
# Epoch 00116: val_loss did not improve from 0.04154
# Epoch 117/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0295 - val_loss: 0.0430
#
# Epoch 00117: val_loss did not improve from 0.04154
# Epoch 118/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0293 - val_loss: 0.0428
#
# Epoch 00118: val_loss did not improve from 0.04154
# Epoch 119/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0291 - val_loss: 0.0425
#
# Epoch 00119: val_loss did not improve from 0.04154
# Epoch 120/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0291 - val_loss: 0.0424
#
# Epoch 00120: val_loss did not improve from 0.04154
# Epoch 121/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0288 - val_loss: 0.0418
#
# Epoch 00121: val_loss did not improve from 0.04154
# Epoch 122/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0289 - val_loss: 0.0421
#
# Epoch 00122: val_loss did not improve from 0.04154
# Epoch 123/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0289 - val_loss: 0.0431
#
# Epoch 00123: val_loss did not improve from 0.04154
# Epoch 124/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0288 - val_loss: 0.0436
#
# Epoch 00124: val_loss did not improve from 0.04154
# Epoch 125/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0287 - val_loss: 0.0421
#
# Epoch 00125: val_loss did not improve from 0.04154
# Epoch 126/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0283 - val_loss: 0.0427
#
# Epoch 00126: val_loss did not improve from 0.04154
# Epoch 127/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0285 - val_loss: 0.0424
#
# Epoch 00127: val_loss did not improve from 0.04154
# Epoch 128/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0284 - val_loss: 0.0424
#
# Epoch 00128: val_loss did not improve from 0.04154
# Epoch 129/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0284 - val_loss: 0.0423
#
# Epoch 00129: val_loss did not improve from 0.04154
# Epoch 130/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0281 - val_loss: 0.0427
#
# Epoch 00130: val_loss did not improve from 0.04154
# Epoch 131/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0284 - val_loss: 0.0438
#
# Epoch 00131: val_loss did not improve from 0.04154
# Epoch 132/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0282 - val_loss: 0.0430
#
# Epoch 00132: val_loss did not improve from 0.04154
# Epoch 133/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0284 - val_loss: 0.0423
#
# Epoch 00133: val_loss did not improve from 0.04154
# Epoch 134/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0281 - val_loss: 0.0422
#
# Epoch 00134: val_loss did not improve from 0.04154
# Epoch 135/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0282 - val_loss: 0.0424
#
# Epoch 00135: val_loss did not improve from 0.04154
# Epoch 136/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0281 - val_loss: 0.0428
#
# Epoch 00136: val_loss did not improve from 0.04154
# Epoch 137/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0276 - val_loss: 0.0429
#
# Epoch 00137: val_loss did not improve from 0.04154
# Epoch 138/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0278 - val_loss: 0.0426
#
# Epoch 00138: val_loss did not improve from 0.04154
# Epoch 139/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0279 - val_loss: 0.0433
#
# Epoch 00139: val_loss did not improve from 0.04154
# Epoch 140/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0278 - val_loss: 0.0426
#
# Epoch 00140: val_loss did not improve from 0.04154
# Epoch 141/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0274 - val_loss: 0.0434
#
# Epoch 00141: val_loss did not improve from 0.04154
# Epoch 142/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0278 - val_loss: 0.0423
#
# Epoch 00142: val_loss did not improve from 0.04154
# Epoch 143/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0273 - val_loss: 0.0432
#
# Epoch 00143: val_loss did not improve from 0.04154
# Epoch 144/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0273 - val_loss: 0.0430
#
# Epoch 00144: val_loss did not improve from 0.04154
# Epoch 145/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0277 - val_loss: 0.0426
#
# Epoch 00145: val_loss did not improve from 0.04154
# Epoch 146/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0277 - val_loss: 0.0430
#
# Epoch 00146: val_loss did not improve from 0.04154
# Epoch 147/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0270 - val_loss: 0.0422
#
# Epoch 00147: val_loss did not improve from 0.04154
# Epoch 148/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0275 - val_loss: 0.0424
#
# Epoch 00148: val_loss did not improve from 0.04154
# Epoch 149/150
# 2375/2375 [==============================] - 21s 9ms/step - loss: 0.0273 - val_loss: 0.0427
#
# Epoch 00149: val_loss did not improve from 0.04154
# Epoch 150/150
# 2375/2375 [==============================] - 22s 9ms/step - loss: 0.0271 - val_loss: 0.0427
#
# Epoch 00150: val_loss did not improve from 0.04154
# Epoch 151/200
# 3166/3166 [==============================] - 25s 8ms/step - loss: 0.0307
# Epoch 152/200
# /usr/local/lib/python3.5/dist-packages/keras/callbacks.py:434: RuntimeWarning: Can save best model only with val_loss available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0304
# Epoch 153/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0302
# Epoch 154/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0295
# Epoch 155/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0300
# Epoch 156/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0299
# Epoch 157/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0297
# Epoch 158/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0294
# Epoch 159/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0293
# Epoch 160/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0296
# Epoch 161/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0290
# Epoch 162/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0292
# Epoch 163/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0294
# Epoch 164/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0289
# Epoch 165/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0291
# Epoch 166/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0292
# Epoch 167/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0290
# Epoch 168/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0289
# Epoch 169/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0291
# Epoch 170/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0289
# Epoch 171/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0287
# Epoch 172/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0286
# Epoch 173/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0288
# Epoch 174/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0283
# Epoch 175/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0286
# Epoch 176/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0283
# Epoch 177/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0283
# Epoch 178/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0283
# Epoch 179/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0283
# Epoch 180/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0281
# Epoch 181/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0280
# Epoch 182/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0282
# Epoch 183/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0279
# Epoch 184/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0278
# Epoch 185/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0278
# Epoch 186/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0280
# Epoch 187/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0276
# Epoch 188/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0277
# Epoch 189/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0279
# Epoch 190/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0275
# Epoch 191/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0279
# Epoch 192/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0276
# Epoch 193/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0273
# Epoch 194/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0277
# Epoch 195/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0274
# Epoch 196/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0272
# Epoch 197/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0277
# Epoch 198/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0276
# Epoch 199/200
# 3166/3166 [==============================] - 26s 8ms/step - loss: 0.0272
# Epoch 200/200
# 3166/3166 [==============================] - 27s 8ms/step - loss: 0.0275
